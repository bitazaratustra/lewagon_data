# %% [markdown]
# # How to properly prevent overfitting

# %% [markdown]
# 🎯 **Goals of this challenge**
# - **`Cross Validate`** a Deep Learning Model
# - Give a **`Validation Set`** to the model
# - Apply two techniques to prevent overfitting:
#     - Use the **`Early Stopping`** criterion to prevent the Neural network from over-learning / over-fitting
#     - **`Regularize`** your network
# - Analyze the **`impact of the batch size and the number of epochs`** on the training of a Neural Network

# %%
# DATA MANIPULATION
import numpy as np

# DATA VISUALIZATION
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data: the `blobs` dataset

# %%
# BLOB DATASET
from sklearn.datasets import make_blobs

# %% [markdown]
# ❓ **Question: generating a "blobs dataset"** ❓
#
# First, let's generate some data using the [`make_blob`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html) function from Scikit-Learn
#
# Generate:
# * 2000 samples with 10 features each
# * There should be 8 classes of blobs (`centers` argument), with `cluster_std` equal to 7.

# %%
X, y = make_blobs(n_samples=2000, centers=8, n_features=10,cluster_std=7,random_state=0)

# %% [markdown]
# ❓ **Question: visualizing the dataset** ❓
#
# All your samples have 10 features.
# Plot one of the dimensions against another.

# %%
# YOUR CODE HERE
plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# ❓ **Question: "encoding" your categorical target** ❓
#
# Use the **to_categorical** function from **tensorflow.keras** to convert `y` to `y_cat` which is the categorical representation of `y` with "*one-hot encoded*" columns.

# %%
from tensorflow.keras.utils import to_categorical
# Out:
# 2022-09-10 11:34:47.852520: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-10 11:34:47.852589: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# YOUR CODE HERE
y_cat = to_categorical(y)

# %% [markdown]
# ## (1) Cross Validation in Deep Learning

# %% [markdown]
# 👩🏻‍🏫 In a previous challenge, we split the dataset into a train set and a test set at the beginning of the notebook.
#
# And then, we started to build different models which were trained on the train set and evaluated on the test set.
#
# So, at the end of the day, we used the test set every time we evaluated our models and different hyperparameters. This is normal: we train on the train set and we evaluate on the test set.
#
# However, we selected our _"best model"_ based on the score of each model. In other words, we _used_ the test set to select our best model, which is a sort of ❗️ `data-leakage` ❗️
#
# 🤔 What should I do?
#
# * A first good practice is to avoid using `random_state` or any deterministic separation between your train and test set. In that case, your test set will change every time you re-run your notebook. But this is far from being sufficient.
#
# * To compare models properly, you have to run a cross-validation, a 10-fold split for instance.
#
# 🧐 If you look at [sklearn.model_selection.cross_validate](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html), this Cross Validation tool is designed for Machine Learning algorithms implemented in Scikit Learn... whereas we have been creating and using Neural Networks from Tensorflow/Keras.
#
# 🔥 Let's discover how to **Cross-Validate a Neural Network**.

# %% [markdown]
# ❓ **Question: designing a Neural Network** ❓
#
# First, write a function that generates a Neural Network with 3 layers:
#
# <u>Architecture</u>
# - an *input layer* with 25 neurons, the `relu` activation function and the appropriate `input_dim`
# - a *hidden layer* with 10 neurons and the `relu` activation function.
# - a *predictive layer* which is suited to the problem at hand (*multiclass classification*)
#
# <u>Compilation</u>
#
# The function should include a compilation method with:
# - the *categorical_crossentropy* loss,
# - the *adam* optimizer
# - the *accuracy* metrics.

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import Sequential

# %%
def initialize_model():
    model = Sequential()
    model.add(layers.Dense(25, activation='relu', input_dim=10))
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(8, activation='softmax'))
    
    model.compile(
    optimizer='adam',
    loss='categorical_crossentropy', 
    metrics = 'accuracy')
    
    return model

# %% [markdown]
# ❓ **Question: Cross-Validating the Neural Net** ❓
#
# 🧑🏻‍💻 Write a _loop_ using the [K-Fold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html) function from Scikit-Learn.
#
# * ✂️ Choose 10 splits to fit your model on the train data
# * 🧪 Evaluate your model on the test data. Store the results of the evaluation into a `results` variable.
#
# _Hints_:
# * ⚖️ Do not forget to standardize your train data before fitting the neural network.
# * 👌 Also, 150 epochs should be sufficient for a first approximation
# * 🤝 As this is your first Deep Learning Cross Validation, you are guided. Uncomment the following cell and follow the steps.
# * ⏳ Notice that we added `%% time` at the beginning of this Jupyter Notebook cell to display its running time and we encourage you to do so whenever you have expensive computations.

# %%
# %%time

from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

kf = KFold(n_splits=10)
kf.get_n_splits(X)

results = []

for train_index, test_index in kf.split(X):
    
#     # Split the data into train and test
    X_train = X[train_index]
    X_test = X[test_index]
    y_train = y_cat[train_index]
    y_test = y_cat[test_index]
    
#     # Scaling your data
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
#     # Initialize the model
    model = initialize_model()
    
#     # Fit the model on the train data
    model.fit(X_train_scaled, y_train, batch_size=32, epochs=150, verbose=0)
    
#     # Evaluate the model on the test data
    results.append(model.evaluate(X_test_scaled, y_test))
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6989 - accuracy: 0.7150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7227 - accuracy: 0.7350
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5912 - accuracy: 0.8050
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7712 - accuracy: 0.7450
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7297 - accuracy: 0.7450
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7630 - accuracy: 0.7200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7436 - accuracy: 0.7450
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7389 - accuracy: 0.7750
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8000 - accuracy: 0.7100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6679 - accuracy: 0.7750
# CPU times: user 3min 35s, sys: 1min 3s, total: 4min 38s
# Wall time: 2min 26s

# %%
for train_index, test_index in kf.split(X):
    print(X[test_index].shape)
    print(X[train_index].shape)
# Out:
# (200, 10)
# (1800, 10)
# (200, 10)
# (1800, 10)
# (200, 10)
# (1800, 10)
# (200, 10)
# (1800, 10)
# (200, 10)
# (1800, 10)
# (200, 10)
# (1800, 10)
# (200, 10)
# (1800, 10)
# (200, 10)
# (1800, 10)
# (200, 10)
# (1800, 10)
# (200, 10)
# (1800, 10)

# %% [markdown]
# ❓ **Question: Performance of the Cross Validated Network** ❓
#
# Print the average accuracy of these 10 folds and the standard deviation of these 10 accuracy values.

# %%
# YOUR CODE HERE
average = np.array(results).mean()
standard_deviation = np.array(results).std()

# %% [markdown]
# ❗ **Remarks about the computational time** ❗
#
# * 🤯 You probably encountered one of the main drawbacks of using a proper cross-validation for a Neural Network: **it takes a lot of time**! Therefore, for the rest of the Deep-Learning module, we will do ***only one split***.
#
# * 👮🏻‍♀️ But remember that this is not entirely correct and, for real-life applications and problems, you are encouraged to use a proper cross-validation technique.
#
# * 💼 In general, what practitioners do, is that they split only once, as you did. And once they get to the end of their optimization, they launch a real cross-validation at 6 PM, go home and get the final results on the next day.

# %% [markdown]
# ❓ **Question: Holdout Method** ❓
#
# For the rest of the exercise (and of the Deep Learning module), split the dataset into a train set and a test set with a 70/30% training to test data ratio.

# %%
# YOUR CODE HERE
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_cat, test_size = 0.3)

# %% [markdown]
# ## (2) How to prevent a Neural Network from overfitting?

# %% [markdown]
# ### (2.1) Early Stopping
#
# 🚦 ***Stop the learning process before overfitting***

# %% [markdown]
# ❓ **Question: illustrating how a Neural Network can easily overfit...** ❓
#
# First things first, let's show that if we train the model for too long (for too many epochs) it will overfit the training data and will not be good at predicting on the test data.
#
# To do this, train the same neural network (⚠️ do not forget to re-initialize it ⚠️) with `validation_data =(X_test, y_test)` and `epochs = 500`. Store the history in a `history` variable.

# %%
# %%time
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping()

model = initialize_model()

history = model.fit(X_train, y_train, 
          batch_size=16, 
          epochs=500, 
          validation_split=0.3)
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 6ms/step - loss: 3.2658 - accuracy: 0.1042 - val_loss: 2.4647 - val_accuracy: 0.1663
# Epoch 2/500
# 62/62 [==============================] - 0s 5ms/step - loss: 2.1406 - accuracy: 0.2319 - val_loss: 1.8652 - val_accuracy: 0.3373
# Epoch 3/500
# 62/62 [==============================] - 0s 6ms/step - loss: 1.7384 - accuracy: 0.3361 - val_loss: 1.6056 - val_accuracy: 0.4323
# Epoch 4/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.5288 - accuracy: 0.4137 - val_loss: 1.4356 - val_accuracy: 0.5036
# Epoch 5/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.3616 - accuracy: 0.5117 - val_loss: 1.2965 - val_accuracy: 0.5534
# Epoch 6/500
# 62/62 [==============================] - 0s 5ms/step - loss: 1.2121 - accuracy: 0.5700 - val_loss: 1.1901 - val_accuracy: 0.5867
# Epoch 7/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.0971 - accuracy: 0.6333 - val_loss: 1.0857 - val_accuracy: 0.6271
# Epoch 8/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.9948 - accuracy: 0.6670 - val_loss: 1.0249 - val_accuracy: 0.6318
# Epoch 9/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.9249 - accuracy: 0.6895 - val_loss: 0.9492 - val_accuracy: 0.6556
# Epoch 10/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.8691 - accuracy: 0.7130 - val_loss: 0.9064 - val_accuracy: 0.6651
# Epoch 11/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.8265 - accuracy: 0.7252 - val_loss: 0.8755 - val_accuracy: 0.6841
# Epoch 12/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.7918 - accuracy: 0.7365 - val_loss: 0.8769 - val_accuracy: 0.6817
# Epoch 13/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.7588 - accuracy: 0.7375 - val_loss: 0.8395 - val_accuracy: 0.6936
# Epoch 14/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.7329 - accuracy: 0.7457 - val_loss: 0.8110 - val_accuracy: 0.7126
# Epoch 15/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.7134 - accuracy: 0.7508 - val_loss: 0.7857 - val_accuracy: 0.7268
# Epoch 16/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6943 - accuracy: 0.7640 - val_loss: 0.8037 - val_accuracy: 0.7078
# Epoch 17/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6762 - accuracy: 0.7651 - val_loss: 0.7827 - val_accuracy: 0.7221
# Epoch 18/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6669 - accuracy: 0.7702 - val_loss: 0.7818 - val_accuracy: 0.7340
# Epoch 19/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6556 - accuracy: 0.7753 - val_loss: 0.7796 - val_accuracy: 0.7268
# Epoch 20/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6427 - accuracy: 0.7753 - val_loss: 0.7743 - val_accuracy: 0.7221
# Epoch 21/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6339 - accuracy: 0.7763 - val_loss: 0.7890 - val_accuracy: 0.7292
# Epoch 22/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6266 - accuracy: 0.7773 - val_loss: 0.7814 - val_accuracy: 0.7245
# Epoch 23/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6171 - accuracy: 0.7783 - val_loss: 0.7824 - val_accuracy: 0.7221
# Epoch 24/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6061 - accuracy: 0.7814 - val_loss: 0.7834 - val_accuracy: 0.7245
# Epoch 25/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5993 - accuracy: 0.7896 - val_loss: 0.7958 - val_accuracy: 0.7197
# Epoch 26/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5896 - accuracy: 0.7926 - val_loss: 0.7915 - val_accuracy: 0.7221
# Epoch 27/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5826 - accuracy: 0.7875 - val_loss: 0.7828 - val_accuracy: 0.7292
# Epoch 28/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5874 - accuracy: 0.7794 - val_loss: 0.7845 - val_accuracy: 0.7221
# Epoch 29/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5690 - accuracy: 0.7947 - val_loss: 0.7833 - val_accuracy: 0.7316
# Epoch 30/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5658 - accuracy: 0.8029 - val_loss: 0.8153 - val_accuracy: 0.7055
# Epoch 31/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5634 - accuracy: 0.8018 - val_loss: 0.7873 - val_accuracy: 0.7292
# Epoch 32/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5538 - accuracy: 0.8069 - val_loss: 0.7841 - val_accuracy: 0.7316
# Epoch 33/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5582 - accuracy: 0.7937 - val_loss: 0.7819 - val_accuracy: 0.7363
# Epoch 34/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5466 - accuracy: 0.8029 - val_loss: 0.7762 - val_accuracy: 0.7340
# Epoch 35/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5429 - accuracy: 0.8069 - val_loss: 0.7878 - val_accuracy: 0.7292
# Epoch 36/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5403 - accuracy: 0.8039 - val_loss: 0.7790 - val_accuracy: 0.7245
# Epoch 37/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5349 - accuracy: 0.8029 - val_loss: 0.8099 - val_accuracy: 0.7268
# Epoch 38/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5304 - accuracy: 0.8069 - val_loss: 0.7929 - val_accuracy: 0.7363
# Epoch 39/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5259 - accuracy: 0.8080 - val_loss: 0.7781 - val_accuracy: 0.7221
# Epoch 40/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5214 - accuracy: 0.8080 - val_loss: 0.8210 - val_accuracy: 0.7197
# Epoch 41/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5191 - accuracy: 0.8069 - val_loss: 0.7883 - val_accuracy: 0.7316
# Epoch 42/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5147 - accuracy: 0.8192 - val_loss: 0.8225 - val_accuracy: 0.7245
# Epoch 43/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5098 - accuracy: 0.8059 - val_loss: 0.7966 - val_accuracy: 0.7316
# Epoch 44/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5053 - accuracy: 0.8172 - val_loss: 0.8088 - val_accuracy: 0.7268
# Epoch 45/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5081 - accuracy: 0.8161 - val_loss: 0.8279 - val_accuracy: 0.7221
# Epoch 46/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5055 - accuracy: 0.8080 - val_loss: 0.8015 - val_accuracy: 0.7363
# Epoch 47/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4957 - accuracy: 0.8223 - val_loss: 0.8251 - val_accuracy: 0.7221
# Epoch 48/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4944 - accuracy: 0.8304 - val_loss: 0.8167 - val_accuracy: 0.7316
# Epoch 49/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4963 - accuracy: 0.8243 - val_loss: 0.8127 - val_accuracy: 0.7292
# Epoch 50/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4894 - accuracy: 0.8284 - val_loss: 0.8105 - val_accuracy: 0.7316
# Epoch 51/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4859 - accuracy: 0.8304 - val_loss: 0.8385 - val_accuracy: 0.7268
# Epoch 52/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4871 - accuracy: 0.8253 - val_loss: 0.8181 - val_accuracy: 0.7387
# Epoch 53/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4826 - accuracy: 0.8223 - val_loss: 0.8165 - val_accuracy: 0.7268
# Epoch 54/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0
500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4098 - accuracy: 0.8560 - val_loss: 0.9156 - val_accuracy: 0.7173
# Epoch 85/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.8570 - val_loss: 0.9028 - val_accuracy: 0.7173
# Epoch 86/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4054 - accuracy: 0.8601 - val_loss: 0.9712 - val_accuracy: 0.6865
# Epoch 87/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4150 - accuracy: 0.8509 - val_loss: 0.9115 - val_accuracy: 0.7173
# Epoch 88/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4041 - accuracy: 0.8529 - val_loss: 0.8962 - val_accuracy: 0.7078
# Epoch 89/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4047 - accuracy: 0.8550 - val_loss: 0.9326 - val_accuracy: 0.7078
# Epoch 90/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4113 - accuracy: 0.8478 - val_loss: 0.9141 - val_accuracy: 0.7055
# Epoch 91/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3990 - accuracy: 0.8580 - val_loss: 0.9193 - val_accuracy: 0.7150
# Epoch 92/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3952 - accuracy: 0.8621 - val_loss: 0.9195 - val_accuracy: 0.7150
# Epoch 93/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4003 - accuracy: 0.8539 - val_loss: 0.9370 - val_accuracy: 0.7173
# Epoch 94/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3962 - accuracy: 0.8498 - val_loss: 0.9250 - val_accuracy: 0.7126
# Epoch 95/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3891 - accuracy: 0.8590 - val_loss: 0.9211 - val_accuracy: 0.7173
# Epoch 96/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3918 - accuracy: 0.8550 - val_loss: 0.9174 - val_accuracy: 0.7102
# Epoch 97/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3878 - accuracy: 0.8580 - val_loss: 0.9493 - val_accuracy: 0.7268
# Epoch 98/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3932 - accuracy: 0.8478 - val_loss: 0.9371 - val_accuracy: 0.7150
# Epoch 99/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3834 - accuracy: 0.8641 - val_loss: 0.9273 - val_accuracy: 0.7078
# Epoch 100/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3870 - accuracy: 0.8641 - val_loss: 0.9334 - val_accuracy: 0.7221
# Epoch 101/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3825 - accuracy: 0.8621 - val_loss: 0.9559 - val_accuracy: 0.7150
# Epoch 102/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3821 - accuracy: 0.8631 - val_loss: 0.9502 - val_accuracy: 0.7126
# Epoch 103/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3816 - accuracy: 0.8682 - val_loss: 0.9438 - val_accuracy: 0.7197
# Epoch 104/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3803 - accuracy: 0.8662 - val_loss: 0.9569 - val_accuracy: 0.7173
# Epoch 105/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3821 - accuracy: 0.8652 - val_loss: 0.9551 - val_accuracy: 0.7221
# Epoch 106/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3801 - accuracy: 0.8652 - val_loss: 0.9595 - val_accuracy: 0.7150
# Epoch 107/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3747 - accuracy: 0.8652 - val_loss: 0.9586 - val_accuracy: 0.7126
# Epoch 108/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3763 - accuracy: 0.8641 - val_loss: 0.9785 - val_accuracy: 0.7173
# Epoch 109/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3695 - accuracy: 0.8652 - val_loss: 0.9887 - val_accuracy: 0.7150
# Epoch 110/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.3693 - accuracy: 0.8652 - val_loss: 0.9773 - val_accuracy: 0.7221
# Epoch 111/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3665 - accuracy: 0.8713 - val_loss: 0.9967 - val_accuracy: 0.7221
# Epoch 112/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3668 - accuracy: 0.8713 - val_loss: 0.9783 - val_accuracy: 0.7197
# Epoch 113/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3685 - accuracy: 0.8631 - val_loss: 1.0146 - val_accuracy: 0.7055
# Epoch 114/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.8652 - val_loss: 1.0015 - val_accuracy: 0.7102
# Epoch 115/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3643 - accuracy: 0.8652 - val_loss: 0.9856 - val_accuracy: 0.7173
# Epoch 116/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3699 - accuracy: 0.8611 - val_loss: 1.0247 - val_accuracy: 0.7055
# Epoch 117/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3642 - accuracy: 0.8621 - val_loss: 1.0311 - val_accuracy: 0.7007
# Epoch 118/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3596 - accuracy: 0.8611 - val_loss: 1.0036 - val_accuracy: 0.7102
# Epoch 119/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3591 - accuracy: 0.8703 - val_loss: 1.0115 - val_accuracy: 0.7126
# Epoch 120/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3560 - accuracy: 0.8693 - val_loss: 1.0290 - val_accuracy: 0.7173
# Epoch 121/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3532 - accuracy: 0.8733 - val_loss: 1.0321 - val_accuracy: 0.7078
# Epoch 122/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3534 - accuracy: 0.8693 - val_loss: 1.0171 - val_accuracy: 0.7126
# Epoch 123/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3524 - accuracy: 0.8682 - val_loss: 1.0241 - val_accuracy: 0.7197
# Epoch 124/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3510 - accuracy: 0.8713 - val_loss: 1.0288 - val_accuracy: 0.7078
# Epoch 125/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3502 - accuracy: 0.8723 - val_loss: 1.0662 - val_accuracy: 0.7031
# Epoch 126/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3505 - accuracy: 0.8723 - val_loss: 1.0677 - val_accuracy: 0.7102
# Epoch 127/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3517 - accuracy: 0.8662 - val_loss: 1.0537 - val_accuracy: 0.7150
# Epoch 128/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3448 - accuracy: 0.8754 - val_loss: 1.1006 - val_accuracy: 0.7055
# Epoch 129/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3523 - accuracy: 0.8693 - val_loss: 1.0596 - val_accuracy: 0.7102
# Epoch 130/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3417 - accuracy: 0.8733 - val_loss: 1.0772 - val_accuracy: 0.7126
# Epoch 131/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3430 - accuracy: 0.8713 - val_loss: 1.0724 - val_accuracy: 0.7102
# Epoch 132/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3380 - accuracy: 0.8774 - val_loss: 1.0851 - val_accuracy: 0.6983
# Epoch 133/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3392 - accuracy: 0.8784 - val_loss: 1.0837 - val_accuracy: 0.7126
# Epoch 134/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3442 - accuracy: 0.8723 - val_loss: 1.1089 - val_accuracy: 0.7007
# Epoch 135/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3417 - accuracy: 0.8713 - val_loss: 1.0837 - val_accuracy: 0.7173
# Epoch 136/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3360 - accuracy: 0.8764 - val_loss: 1.1023 - val_accuracy: 0.7031
# Epoch 137/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3342 - accuracy: 0.8805 - val_loss: 1.1034 - val_accuracy: 0.7007
# Epoch 138/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3303 - accuracy: 0.8754 - val_loss: 1.0964 - val_accuracy: 0.7173
# Epoch 139/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3409 - accuracy: 0.8703 - val_loss: 1.1259 - val_accuracy: 0.7078
# Epoch 140/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3305 - accuracy: 0.8795 - val_loss: 1.1097 - val_accuracy: 0.7078
# Epoch 141/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3304 - accuracy: 0.8825 - val_loss: 1.1008 - val_accuracy: 0.7126
# Epoch 142/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3331 - accuracy: 0.8774 - val_loss: 1.1142 - val_accuracy: 0.7078
# Epoch 143/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3266 - accuracy: 0.8805 - val_loss: 1.1112 - val_accuracy: 0.7102
# Epoch 144/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3275 - accuracy: 0.8733 - val_loss: 1.1050 - val_accuracy: 0.7078
# Epoch 145/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.
500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2999 - accuracy: 0.8897 - val_loss: 1.3202 - val_accuracy: 0.6888
# Epoch 177/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2987 - accuracy: 0.8927 - val_loss: 1.2736 - val_accuracy: 0.6912
# Epoch 178/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2885 - accuracy: 0.8948 - val_loss: 1.3058 - val_accuracy: 0.6865
# Epoch 179/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2865 - accuracy: 0.8968 - val_loss: 1.2908 - val_accuracy: 0.6912
# Epoch 180/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2854 - accuracy: 0.8979 - val_loss: 1.3206 - val_accuracy: 0.7007
# Epoch 181/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2867 - accuracy: 0.8917 - val_loss: 1.3681 - val_accuracy: 0.6865
# Epoch 182/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2824 - accuracy: 0.8989 - val_loss: 1.2985 - val_accuracy: 0.6960
# Epoch 183/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2843 - accuracy: 0.8979 - val_loss: 1.3057 - val_accuracy: 0.6983
# Epoch 184/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2875 - accuracy: 0.8999 - val_loss: 1.3323 - val_accuracy: 0.7007
# Epoch 185/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2905 - accuracy: 0.8958 - val_loss: 1.3482 - val_accuracy: 0.7007
# Epoch 186/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2805 - accuracy: 0.9030 - val_loss: 1.3353 - val_accuracy: 0.6912
# Epoch 187/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2851 - accuracy: 0.8979 - val_loss: 1.3242 - val_accuracy: 0.6912
# Epoch 188/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2774 - accuracy: 0.9019 - val_loss: 1.3441 - val_accuracy: 0.6960
# Epoch 189/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.2783 - accuracy: 0.9019 - val_loss: 1.3583 - val_accuracy: 0.6960
# Epoch 190/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.2808 - accuracy: 0.9050 - val_loss: 1.3538 - val_accuracy: 0.6888
# Epoch 191/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2853 - accuracy: 0.8927 - val_loss: 1.3833 - val_accuracy: 0.6888
# Epoch 192/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2841 - accuracy: 0.8979 - val_loss: 1.3865 - val_accuracy: 0.6841
# Epoch 193/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.2734 - accuracy: 0.9050 - val_loss: 1.4240 - val_accuracy: 0.6936
# Epoch 194/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2753 - accuracy: 0.8999 - val_loss: 1.4055 - val_accuracy: 0.6841
# Epoch 195/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2731 - accuracy: 0.9050 - val_loss: 1.3814 - val_accuracy: 0.6960
# Epoch 196/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2773 - accuracy: 0.9040 - val_loss: 1.4207 - val_accuracy: 0.7007
# Epoch 197/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2738 - accuracy: 0.9081 - val_loss: 1.4357 - val_accuracy: 0.6936
# Epoch 198/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2692 - accuracy: 0.9111 - val_loss: 1.3980 - val_accuracy: 0.6888
# Epoch 199/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2753 - accuracy: 0.8968 - val_loss: 1.4299 - val_accuracy: 0.6912
# Epoch 200/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2729 - accuracy: 0.9040 - val_loss: 1.4045 - val_accuracy: 0.6936
# Epoch 201/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2676 - accuracy: 0.9060 - val_loss: 1.4260 - val_accuracy: 0.6912
# Epoch 202/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.2757 - accuracy: 0.9030 - val_loss: 1.4424 - val_accuracy: 0.6817
# Epoch 203/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2658 - accuracy: 0.9111 - val_loss: 1.4735 - val_accuracy: 0.6817
# Epoch 204/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2712 - accuracy: 0.8989 - val_loss: 1.4296 - val_accuracy: 0.6841
# Epoch 205/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2681 - accuracy: 0.9040 - val_loss: 1.4289 - val_accuracy: 0.6865
# Epoch 206/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.2699 - accuracy: 0.9019 - val_loss: 1.4484 - val_accuracy: 0.6841
# Epoch 207/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.
500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2212 - accuracy: 0.9244 - val_loss: 1.7933 - val_accuracy: 0.6841
# Epoch 269/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2286 - accuracy: 0.9203 - val_loss: 1.8238 - val_accuracy: 0.6746
# Epoch 270/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2263 - accuracy: 0.9162 - val_loss: 1.8363 - val_accuracy: 0.6746
# Epoch 271/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2310 - accuracy: 0.9234 - val_loss: 1.8566 - val_accuracy: 0.6841
# Epoch 272/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2209 - accuracy: 0.9234 - val_loss: 1.8305 - val_accuracy: 0.6698
# Epoch 273/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2245 - accuracy: 0.9265 - val_loss: 1.8683 - val_accuracy: 0.6651
# Epoch 274/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2150 - accuracy: 0.9285 - val_loss: 1.8836 - val_accuracy: 0.6817
# Epoch 275/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2183 - accuracy: 0.9295 - val_loss: 1.8616 - val_accuracy: 0.6793
# Epoch 276/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2129 - accuracy: 0.9346 - val_loss: 1.8499 - val_accuracy: 0.6770
# Epoch 277/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.2228 - accuracy: 0.9203 - val_loss: 1.8460 - val_accuracy: 0.6888
# Epoch 278/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.2225 - accuracy: 0.9213 - val_loss: 1.8668 - val_accuracy: 0.6793
# Epoch 279/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2158 - accuracy: 0.9265 - val_loss: 1.8607 - val_accuracy: 0.6793
# Epoch 280/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2127 - accuracy: 0.9316 - val_loss: 1.8361 - val_accuracy: 0.6770
# Epoch 281/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2147 - accuracy: 0.9234 - val_loss: 1.8506 - val_accuracy: 0.6770
# Epoch 282/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2121 - accuracy: 0.9265 - val_loss: 1.8834 - val_accuracy: 0.6888
# Epoch 283/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2076 - accuracy: 0.9295 - val_loss: 1.8904 - val_accuracy: 0.6841
# Epoch 284/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2094 - accuracy: 0.9295 - val_loss: 1.9031 - val_accuracy: 0.6746
# Epoch 285/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2136 - accuracy: 0.9295 - val_loss: 1.8837 - val_accuracy: 0.6698
# Epoch 286/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.2098 - accuracy: 0.9285 - val_loss: 1.8939 - val_accuracy: 0.6841
# Epoch 287/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2047 - accuracy: 0.9356 - val_loss: 1.9143 - val_accuracy: 0.6793
# Epoch 288/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2071 - accuracy: 0.9326 - val_loss: 1.9202 - val_accuracy: 0.6841
# Epoch 289/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2055 - accuracy: 0.9356 - val_loss: 1.9532 - val_accuracy: 0.6817
# Epoch 290/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2069 - accuracy: 0.9295 - val_loss: 1.9563 - val_accuracy: 0.6888
# Epoch 291/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2021 - accuracy: 0.9377 - val_loss: 1.9169 - val_accuracy: 0.6888
# Epoch 292/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2037 - accuracy: 0.9367 - val_loss: 2.0261 - val_accuracy: 0.6746
# Epoch 293/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2019 - accuracy: 0.9346 - val_loss: 1.9732 - val_accuracy: 0.6698
# Epoch 294/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2005 - accuracy: 0.9387 - val_loss: 2.0052 - val_accuracy: 0.6651
# Epoch 295/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.1982 - accuracy: 0.9316 - val_loss: 2.0266 - val_accuracy: 0.6746
# Epoch 296/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.1984 - accuracy: 0.9367 - val_loss: 2.0150 - val_accuracy: 0.6865
# Epoch 297/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2101 - accuracy: 0.9305 - val_loss: 2.0283 - val_accuracy: 0.6627
# Epoch 298/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.2027 - accuracy: 0.9275 - val_loss: 1.9841 - val_accuracy: 0.6841
# Epoch 299/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.
500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1079 - accuracy: 0.9642 - val_loss: 3.4521 - val_accuracy: 0.6437
# Epoch 476/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1102 - accuracy: 0.9673 - val_loss: 3.4311 - val_accuracy: 0.6508
# Epoch 477/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1019 - accuracy: 0.9704 - val_loss: 3.5292 - val_accuracy: 0.6461
# Epoch 478/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1037 - accuracy: 0.9734 - val_loss: 3.4912 - val_accuracy: 0.6390
# Epoch 479/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1040 - accuracy: 0.9673 - val_loss: 3.5470 - val_accuracy: 0.6437
# Epoch 480/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1039 - accuracy: 0.9704 - val_loss: 3.5275 - val_accuracy: 0.6437
# Epoch 481/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 0.9714 - val_loss: 3.5210 - val_accuracy: 0.6508
# Epoch 482/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.1387 - accuracy: 0.9530 - val_loss: 3.4934 - val_accuracy: 0.6366
# Epoch 483/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.9591 - val_loss: 3.5353 - val_accuracy: 0.6532
# Epoch 484/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1090 - accuracy: 0.9673 - val_loss: 3.5221 - val_accuracy: 0.6437
# Epoch 485/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1010 - accuracy: 0.9694 - val_loss: 3.5158 - val_accuracy: 0.6461
# Epoch 486/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.1012 - accuracy: 0.9704 - val_loss: 3.5179 - val_accuracy: 0.6508
# Epoch 487/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1077 - accuracy: 0.9683 - val_loss: 3.6117 - val_accuracy: 0.6413
# Epoch 488/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1023 - accuracy: 0.9704 - val_loss: 3.6074 - val_accuracy: 0.6461
# Epoch 489/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1028 - accuracy: 0.9663 - val_loss: 3.5704 - val_accuracy: 0.6413
# Epoch 490/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1076 - accuracy: 0.9653 - val_loss: 3.6363 - val_accuracy: 0.6437
# Epoch 491/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.1055 - accuracy: 0.9694 - val_loss: 3.5795 - val_accuracy: 0.6485
# Epoch 492/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1039 - accuracy: 0.9673 - val_loss: 3.6040 - val_accuracy: 0.6318
# Epoch 493/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1032 - accuracy: 0.9642 - val_loss: 3.6394 - val_accuracy: 0.6413
# Epoch 494/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1046 - accuracy: 0.9704 - val_loss: 3.6309 - val_accuracy: 0.6461
# Epoch 495/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1007 - accuracy: 0.9694 - val_loss: 3.5725 - val_accuracy: 0.6508
# Epoch 496/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1021 - accuracy: 0.9724 - val_loss: 3.6663 - val_accuracy: 0.6437
# Epoch 497/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1501 - accuracy: 0.9530 - val_loss: 3.6232 - val_accuracy: 0.6485
# Epoch 498/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1106 - accuracy: 0.9591 - val_loss: 3.6250 - val_accuracy: 0.6485
# Epoch 499/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.1011 - accuracy: 0.9704 - val_loss: 3.6618 - val_accuracy: 0.6437
# Epoch 500/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.0972 - accuracy: 0.9714 - val_loss: 3.6670 - val_accuracy: 0.6485
# CPU times: user 2min 25s, sys: 49.6 s, total: 3min 14s
# Wall time: 2min 22s

# %% [markdown]
# ❓ **Question: your Neural Network's performance** ❓
#
# Evaluate the model on the test set and print the accuracy.

# %%
# YOUR CODE HERE
model.evaluate(X_test, y_test)[1]
# Out:
# 19/19 [==============================] - 0s 2ms/step - loss: 3.4897 - accuracy: 0.6517
# 0.6516666412353516

# %% [markdown]
# ❓ **Question: Learnings about number of epochs** ❓
#
# Plot the history of the model with `plot_loss_accuracy` function that we coded for you.
#
# What do you observe?

# %%
def plot_loss_accuracy(history, title=None):
    fig, ax = plt.subplots(1,2, figsize=(20,7))
    
    # --- LOSS --- 
    
    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])
    ax[0].set_title('Model loss')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylim((0,3))
    ax[0].legend(['Train', 'Test'], loc='best')
    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)
    
    # --- ACCURACY
    
    ax[1].plot(history.history['accuracy'])
    ax[1].plot(history.history['val_accuracy'])
    ax[1].set_title('Model Accuracy')
    ax[1].set_ylabel('Accuracy')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='best')
    ax[1].set_ylim((0,1))
    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)
    
    if title:
        fig.suptitle(title)

# %%
# YOUR CODE HERE
plot_loss_accuracy(history)

# %% [markdown]
# > YOUR ANSWER HERE

# %% [markdown]
# 👩🏻‍🏫 We clearly see that ***the number of epochs we choose has a strong influence on the final results***:
#
# * **INSUFFICIENT NUMBER OF EPOCHS $\implies$ UNDERFITTING**:
#     * The algorithm is not optimal as its ***loss function has not converged yet***,
#     * i.e. it hasn't learned enough from the training data.
# * **TOO MANY EPOCHS** $\implies$ **OVERFITTING**:
#     * Our neural network has ***learned too much from the training data***, even its noisy information...
#     * and the algorithm ***does not generalize well on test data***.
#
# 🚦 Basically, what we want is to do is ***stop the algorithm when the test loss is minimal*** (or when the test metrics is maximal).

# %% [markdown]
# ---
#
# 🧑🏻‍🏫 Let's introduce the **`Early Stopping`** criterion.
#
# The Early Stopping criterion is a way to ***automatically stop training of the algorithm*** before reaching the number of epochs that was originally set.
#
# 🕵🏻‍♂️ How does it work?
#
# > Basically, it uses part of the dataset to check whether the "test" loss has stopped improving. You cannot use the test data itself to check that, that would be data leakage... Instead, we will ***use a subset of the initial training data***, called the ***validation set***.
#
#
# <img src="validation_set.png" alt="Validation set" style="height:200px;"/>
#
# ✂️ To split the training data, we use the **`validation_split`** keyword in the **`.fit()`**: it sets the percentage of data from the initial training set to be used in the **validation set**.
#
# ❗️If you select a _validation_split_ of 30% for example, the last 30% rows of the training set will be used in the validation set. You can use **`shuffle = True`** to add some randomness.
#
# 💡 On top of the _validation_split_, we use the **`callbacks`** keyword in the **`.fit()`** to call the Early Stopping criterion at the end of each epoch. You can check additional information in the ["train_and_evaluate" documentation for Tensorflow/Keras](https://www.tensorflow.org/guide/keras/train_and_evaluate)

# %% [markdown]
# ---
#
# ❓ **Question: Observing the Early Stopping criterion** ❓
#
# Run the following code and plot the history.

# %%
# %%time

from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping()

model = initialize_model()

# Fit the model on the train data
history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 500,
                    batch_size = 16, 
                    verbose = 1, 
                    callbacks = [es])
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 6ms/step - loss: 3.8070 - accuracy: 0.1083 - val_loss: 2.6504 - val_accuracy: 0.1520
# Epoch 2/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.2923 - accuracy: 0.2053 - val_loss: 2.1282 - val_accuracy: 0.2565
# CPU times: user 1.26 s, sys: 149 ms, total: 1.41 s
# Wall time: 1.07 s

# %% [markdown]
# ❓ **Question: Evaluate this model that was stopped earlier** ❓
#
# _(Also look at the historical losses)_

# %%
# YOUR CODE HERE
model.evaluate(X_test, y_test)
# Out:
# 19/19 [==============================] - 0s 2ms/step - loss: 2.0050 - accuracy: 0.2500
# [2.005039691925049, 0.25]

# %% [markdown]
# ❗ **The problem with a strict Early Stopping** ❗
#
# * The problem, with this type of approach, is that as soon as the loss of the validation set increases, the model stops.
#
# * However, as a neural network's convergence is stochastic, The loss may slightly increase before decreasing again.
#
# ✅ The `EarlyStopping` criterion has a **`patience`** keyword that ***defines how many consecutive epochs without any loss decrease*** are allowed before we stop the training procedure.

# %% [markdown]
# ❓ **Question: Early Stopping with patience** ❓
#
# Use the `EarlyStopping` criterion with a patience of 30 epochs, plot the results and print the accuracy on the test set

# %%
# YOUR CODE HERE
es = EarlyStopping(patience=30)

model = initialize_model()

history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 500,
                    batch_size = 16, 
                    verbose = 1, 
                    callbacks = [es])
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 6ms/step - loss: 4.2354 - accuracy: 0.1491 - val_loss: 3.2683 - val_accuracy: 0.1710
# Epoch 2/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.4832 - accuracy: 0.2206 - val_loss: 2.2595 - val_accuracy: 0.2375
# Epoch 3/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.9436 - accuracy: 0.2901 - val_loss: 1.8852 - val_accuracy: 0.3040
# Epoch 4/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.6740 - accuracy: 0.3830 - val_loss: 1.6284 - val_accuracy: 0.4086
# Epoch 5/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4618 - accuracy: 0.4627 - val_loss: 1.4049 - val_accuracy: 0.5012
# Epoch 6/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.2642 - accuracy: 0.5301 - val_loss: 1.2264 - val_accuracy: 0.5487
# Epoch 7/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.0985 - accuracy: 0.5935 - val_loss: 1.1026 - val_accuracy: 0.5891
# Epoch 8/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.9735 - accuracy: 0.6313 - val_loss: 1.0123 - val_accuracy: 0.6176
# Epoch 9/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8859 - accuracy: 0.6711 - val_loss: 0.9269 - val_accuracy: 0.6413
# Epoch 10/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8226 - accuracy: 0.6854 - val_loss: 0.9107 - val_accuracy: 0.6508
# Epoch 11/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7685 - accuracy: 0.7079 - val_loss: 0.8807 - val_accuracy: 0.6675
# Epoch 12/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.7348 - accuracy: 0.7232 - val_loss: 0.8571 - val_accuracy: 0.6888
# Epoch 13/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7045 - accuracy: 0.7406 - val_loss: 0.8948 - val_accuracy: 0.6508
# Epoch 14/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6812 - accuracy: 0.7467 - val_loss: 0.8639 - val_accuracy: 0.6746
# Epoch 15/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6640 - accuracy: 0.7446 - val_loss: 0.8433 - val_accuracy: 0.6912
# Epoch 16/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6488 - accuracy: 0.7569 - val_loss: 0.8510 - val_accuracy: 0.6865
# Epoch 17/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6352 - accuracy: 0.7702 - val_loss: 0.8290 - val_accuracy: 0.6912
# Epoch 18/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6236 - accuracy: 0.7640 - val_loss: 0.8243 - val_accuracy: 0.7007
# Epoch 19/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6168 - accuracy: 0.7620 - val_loss: 0.8300 - val_accuracy: 0.6936
# Epoch 20/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6033 - accuracy: 0.7835 - val_loss: 0.8380 - val_accuracy: 0.6983
# Epoch 21/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5933 - accuracy: 0.7753 - val_loss: 0.8357 - val_accuracy: 0.6960
# Epoch 22/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5862 - accuracy: 0.7824 - val_loss: 0.8406 - val_accuracy: 0.7007
# Epoch 23/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.
500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4566 - accuracy: 0.8294 - val_loss: 0.8824 - val_accuracy: 0.7078
# Epoch 55/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4567 - accuracy: 0.8325 - val_loss: 0.8599 - val_accuracy: 0.7173
# Epoch 56/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4502 - accuracy: 0.8417 - val_loss: 0.9011 - val_accuracy: 0.7031
# Epoch 57/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4475 - accuracy: 0.8437 - val_loss: 0.8672 - val_accuracy: 0.7102
# Epoch 58/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4485 - accuracy: 0.8386 - val_loss: 0.8983 - val_accuracy: 0.7078
# Epoch 59/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4482 - accuracy: 0.8345 - val_loss: 0.8827 - val_accuracy: 0.7055
# Epoch 60/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4437 - accuracy: 0.8417 - val_loss: 0.8903 - val_accuracy: 0.7126
# Epoch 61/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4392 - accuracy: 0.8458 - val_loss: 0.9051 - val_accuracy: 0.7031
# Epoch 62/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4445 - accuracy: 0.8345 - val_loss: 0.9038 - val_accuracy: 0.7055

# %%
model.evaluate(X_test, y_test)[1]
# Out:
# 19/19 [==============================] - 0s 2ms/step - loss: 0.8619 - accuracy: 0.7200
# 0.7200000286102295

# %% [markdown]
# 🧑🏻‍🏫 **Remarks**
#
#
# * 📉 The model continues to converge even though its loss function had some consecutive loss increases/decreases w.r.t. to the number of epochs.
#
# * 🤷🏻‍♂️ The `patience` number to select is highly related to the task at hand and there is not any general rule of thumb.
#
# * 🧑🏻‍🏫 If you selected a high patience value for your Early Stopping:
#     * 🤞 Your Neural Net should theoretically still stop training before the end (not always the case if your number of epochs is too low...)
#     * ❗️ Your validation loss will increase again after reaching a minimum value... but ideally, you want it to be as low as possible. The validation loss potentially reaches a minimum for certain weights at a certain epoch.
#         * 🤔 How to collect these weights?
#
# 📚 The Early Stopping criterion enables you to:
# - *stop the convergence*
# - *restore the best weights of the Neural Network when it had the lowest error level (or the best score) on the validation set*, thanks to **`restore_best_weights = True`** (that is set to `False` by default).

# %% [markdown]
# ❓ **Question: restore the best weights of a model** ❓
#
# * Run the model with an Early Stopping criterion that will restore the best weights of the Neural Net
# * Plot the loss and accuracy
# * Print the accuracy on the test set

# %%
# YOUR CODE HERE
es = EarlyStopping(patience=30, restore_best_weights=True )

model = initialize_model()

history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 500,
                    batch_size = 16, 
                    verbose = 1, 
                    callbacks = [es])
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 6ms/step - loss: 4.1769 - accuracy: 0.1267 - val_loss: 2.8049 - val_accuracy: 0.1710
# Epoch 2/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.3439 - accuracy: 0.2043 - val_loss: 2.0465 - val_accuracy: 0.2827
# Epoch 3/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.8635 - accuracy: 0.3023 - val_loss: 1.7562 - val_accuracy: 0.3563
# Epoch 4/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.5947 - accuracy: 0.3820 - val_loss: 1.5394 - val_accuracy: 0.4014
# Epoch 5/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3771 - accuracy: 0.4801 - val_loss: 1.3558 - val_accuracy: 0.4964
# Epoch 6/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.2012 - accuracy: 0.5373 - val_loss: 1.2227 - val_accuracy: 0.5392
# Epoch 7/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.0627 - accuracy: 0.6016 - val_loss: 1.1036 - val_accuracy: 0.6152
# Epoch 8/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.9596 - accuracy: 0.6353 - val_loss: 1.0371 - val_accuracy: 0.6200
# Epoch 9/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8767 - accuracy: 0.6772 - val_loss: 0.9593 - val_accuracy: 0.6865
# Epoch 10/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8147 - accuracy: 0.7109 - val_loss: 0.9162 - val_accuracy: 0.6817
# Epoch 11/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7650 - accuracy: 0.7191 - val_loss: 0.9069 - val_accuracy: 0.6841
# Epoch 12/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7196 - accuracy: 0.7273 - val_loss: 0.8603 - val_accuracy: 0.6912
# Epoch 13/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6855 - accuracy: 0.7457 - val_loss: 0.8652 - val_accuracy: 0.6888
# Epoch 14/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6587 - accuracy: 0.7538 - val_loss: 0.8552 - val_accuracy: 0.6841
# Epoch 15/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6368 - accuracy: 0.7610 - val_loss: 0.8592 - val_accuracy: 0.6960
# Epoch 16/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6191 - accuracy: 0.7773 - val_loss: 0.8426 - val_accuracy: 0.6888
# Epoch 17/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6072 - accuracy: 0.7681 - val_loss: 0.8525 - val_accuracy: 0.7031
# Epoch 18/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5945 - accuracy: 0.7783 - val_loss: 0.8409 - val_accuracy: 0.7007
# Epoch 19/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5834 - accuracy: 0.7865 - val_loss: 0.8328 - val_accuracy: 0.7007
# Epoch 20/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5739 - accuracy: 0.7896 - val_loss: 0.8396 - val_accuracy: 0.6960
# Epoch 21/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5652 - accuracy: 0.7937 - val_loss: 0.8413 - val_accuracy: 0.7031
# Epoch 22/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5594 - accuracy: 0.7998 - val_loss: 0.8359 - val_accuracy: 0.7173
# Epoch 23/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5538 - accuracy: 0.7978 - val_loss: 0.8405 - val_accuracy: 0.7126
# Epoch 24/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5490 - accuracy: 0.7998 - val_loss: 0.8470 - val_accuracy: 0.7031
# Epoch 25/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5439 - accuracy: 0.7967 - val_loss: 0.8325 - val_accuracy: 0.7055
# Epoch 26/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5368 - accuracy: 0.8080 - val_loss: 0.8403 - val_accuracy: 0.7126
# Epoch 27/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5312 - accuracy: 0.8059 - val_loss: 0.8557 - val_accuracy: 0.7102
# Epoch 28/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5261 - accuracy: 0.8090 - val_loss: 0.8468 - val_accuracy: 0.7031
# Epoch 29/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5188 - accuracy: 0.8059 - val_loss: 0.8714 - val_accuracy: 0.7007
# Epoch 30/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5176 - accuracy: 0.8151 - val_loss: 0.8484 - val_accuracy: 0.7102
# Epoch 31/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5112 - accuracy: 0.8151 - val_loss: 0.8500 - val_accuracy: 0.7102
# Epoch 32/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5043 - accuracy: 0.8151 - val_loss: 0.8579 - val_accuracy: 0.7078
# Epoch 33/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5029 - accuracy: 0.8243 - val_loss: 0.8589 - val_accuracy: 0.7102
# Epoch 34/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4996 - accuracy: 0.8284 - val_loss: 0.8676 - val_accuracy: 0.7055
# Epoch 35/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5014 - accuracy: 0.8192 - val_loss: 0.8520 - val_accuracy: 0.7102
# Epoch 36/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4896 - accuracy: 0.8335 - val_loss: 0.8509 - val_accuracy: 0.7150
# Epoch 37/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4928 - accuracy: 0.8223 - val_loss: 0.8717 - val_accuracy: 0.7102
# Epoch 38/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4871 - accuracy: 0.8243 - val_loss: 0.8677 - val_accuracy: 0.7197
# Epoch 39/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4819 - accuracy: 0.8264 - val_loss: 0.8734 - val_accuracy: 0.7055
# Epoch 40/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4805 - accuracy: 0.8304 - val_loss: 0.8726 - val_accuracy: 0.7102
# Epoch 41/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4792 - accuracy: 0.8315 - val_loss: 0.8681 - val_accuracy: 0.7126
# Epoch 42/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4737 - accuracy: 0.8284 - val_loss: 0.8839 - val_accuracy: 0.7102
# Epoch 43/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4689 - accuracy: 0.8315 - val_loss: 0.8761 - val_accuracy: 0.7173
# Epoch 44/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4670 - accuracy: 0.8304 - val_loss: 0.8797 - val_accuracy: 0.7197
# Epoch 45/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4663 - accuracy: 0.8335 - val_loss: 0.8979 - val_accuracy: 0.7150
# Epoch 46/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4607 - accuracy: 0.8294 - val_loss: 0.8942 - val_accuracy: 0.7150
# Epoch 47/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4559 - accuracy: 0.8407 - val_loss: 0.9110 - val_accuracy: 0.7055
# Epoch 48/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4532 - accuracy: 0.8304 - val_loss: 0.9045 - val_accuracy: 0.7150
# Epoch 49/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4511 - accuracy: 0.8345 - val_loss: 0.9047 - val_accuracy: 0.7126
# Epoch 50/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4535 - accuracy: 0.8325 - val_loss: 0.9061 - val_accuracy: 0.7102
# Epoch 51/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4437 - accuracy: 0.8417 - val_loss: 0.9294 - val_accuracy: 0.7031
# Epoch 52/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4429 - accuracy: 0.8447 - val_loss: 0.9101 - val_accuracy: 0.7150
# Epoch 53/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4375 - accuracy: 0.8478 - val_loss: 0.9367 - val_accuracy: 0.6936
# Epoch 54/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4350 - accuracy: 0.8427 - val_loss: 0.9176 - val_accuracy: 0.7126
# Epoch 55/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4346 - accuracy: 0.8478 - val_loss: 0.9201 - val_accuracy: 0.7055

# %%
plot_loss_accuracy(history)

# %% [markdown]
# 🥡 <u>Takeaways from the Early Stopping criterion</u>:
#
# * You can look at the [Early Stopping documentation](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping) to play with other parameters
#
# *  No longer need to have a look at the number of epochs as long as the model hits the stopping criterion. So, in the future, you should set a large number of epochs and the Early Stopping criterion will take care of stopping the training procedure before the model overfits!

# %% [markdown]
# ### (2.2) Batch-size & Epochs
#
# 🕵️‍♀️ Let's investigate the impact of the batch size on training a Neural Network and how we can use it to control how fast the parameters are updated.

# %% [markdown]
# ❓ **Question: playing with the batch size** ❓
#
# Let's run the previous model with ***different batch sizes*** (with the Early Stopping criterion included) and plot the results.
#
# 👉 Run the following cell

# %%
# %%time
# RUN THIS CELL
es = EarlyStopping(patience=20, restore_best_weights=True)

for batch_size in [1, 4, 32]:
    
    model = initialize_model()

    history = model.fit(X_train, y_train,
                        validation_split = 0.3,
                        epochs = 500,
                        batch_size = batch_size, 
                        verbose = 0, 
                        callbacks = [es])

    results = model.evaluate(X_test, y_test, verbose=0)
    plot_loss_accuracy(history, title=f'------ BATCH SIZE {batch_size} ------\n The accuracy on the test set is of {results[1]:.2f}')
# Out:
# CPU times: user 1min 44s, sys: 30.3 s, total: 2min 14s
# Wall time: 1min 13s

# %% [markdown]
# ❓ **Question: impact of the batch size on the convergence of a Neural Network** ❓
#
# Look at the oscillations of the accuracy and the loss with respect to the batch size number.
#
# Is this coherent with what we saw when playing with the Tensorflow Playground?

# %% [markdown]
# > Your answer here

# %% [markdown]
# ❓ **Questions about the number of parameters' updates** ❓
#
# * How many optimizations of the weights are done within one epoch (with respect to the number of observations and the batch size)?
# * Does one epoch have more weight updates with a large or a small batch size?

# %% [markdown]
# > Your answer here

# %% [markdown]
# <details>
#     <summary><i>Explanations</i></summary>
#
#
# ***`BEGIN_EXPLANATIONS`***
#
# Copy-paste this code in a new cell, run it and observe.
#
# ```python
# print(f"There are {X_train.shape[0]} rows in the training set")
#
# batch_size = 16
# epochs = 2
#
# model = initialize_model()
#
# history = model.fit(X_train,
#                     y_train,
#                     validation_split = 0.3,
#                     epochs = epochs,
#                     batch_size = batch_size,
#                     verbose = 1)
# ```
#
#
# <u><b><i>Number of parameters' updates:</i></b></u>
#
# * There are 1400 rows in the training set:
#     * $ 70 \% \times 1400 = 980 $ rows are used as the train set within the training set
#     * $ 30 \% \times 1400 = 420 $ rows are used as the validation set
#
# * For each epoch, we run a forward/backward propagation $ \large \lceil \frac{980}{batch size} \rceil = \lceil \frac{980}{16}\rceil = 62$ times
#
# * Without the Early Stopping Criterion, we will have overall _number of_ $ epochs \times 62 = 2 \times 62 = 124 $ iterations
#
# <u><b><i>Impact of the batch size:</i></b></u>
#
# The smaller the batch size
#
# $ \implies $ The more sub-iterations will be done
#
# $ \implies $ Parameters will be updated more frequently
#
# $ \implies $ We may need less epochs
#
# _(but we also don't care as much about the number of epochs if we use an Early Stopping Criterion with patience anyway)_
#
# ***`END_EXPLANATIONS`***
#
# </details>

# %%
print(f"There are {X_train.shape[0]} rows in the training set")

batch_size = 16
epochs = 2

model = initialize_model()

history = model.fit(X_train, 
                    y_train,
                    validation_split = 0.3,
                    epochs = epochs,
                    batch_size = batch_size, 
                    verbose = 1)
# Out:
# There are 1400 rows in the training set
# Epoch 1/2
# 62/62 [==============================] - 1s 5ms/step - loss: 3.5863 - accuracy: 0.2145 - val_loss: 2.4174 - val_accuracy: 0.3040
# Epoch 2/2
# 62/62 [==============================] - 0s 3ms/step - loss: 2.0708 - accuracy: 0.3422 - val_loss: 1.9231 - val_accuracy: 0.3539

# %%
batch_size = 16
epochs = 2

model = initialize_model()

history = model.fit(X_train, 
                    y_train,
                    validation_split = 0.3,
                    epochs = epochs,
                    batch_size = batch_size, 
                    verbose = 1)
# Out:
# Epoch 1/2
# 62/62 [==============================] - 1s 6ms/step - loss: 3.2284 - accuracy: 0.1665 - val_loss: 2.2749 - val_accuracy: 0.2518
# Epoch 2/2
# 62/62 [==============================] - 0s 3ms/step - loss: 1.9626 - accuracy: 0.3013 - val_loss: 1.7027 - val_accuracy: 0.3492

# %% [markdown]
# ### (2.3) Regularization

# %% [markdown]
# ❗️ ***Neural Networks with complex architectures can quickly lead to overfitting*** (_"too many" layers and/or neurons..._). ❗️
#
# 🔥 But as Dense Neural Networks are just activated linear regressions, the weights can be constrained using L1, L2 or L1-L2 penalties!
#
#
# 🚓 So, let's apply some L2 or L1 penalties to these neurons. As in Machine Learning, these penalties are called ***`Regularizers`***.
#
#
#
# 📚 <a href="https://www.tensorflow.org/api_docs/python/tf/keras/regularizers">**tensorflow/keras/regularizers**</a>

# %% [markdown]
# ❓ **Initial Question: observing overfitting one more time before regularizing...**❓
#
# * First, let's initialize a model that has too many parameters for the task such that it overfits the training data quickly. _To that purpose, let's not use any Early Stopping criterion._
#
# 🎁 Let's not waste time re-coding something that you are now used to, just run the following cell and observe what is happening 👇

# %%
# RUN THIS CELL

# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model compilation
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 3. Training 
history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
                    batch_size = 16, 
                    verbose=0)

# 4. Evaluation
results_train = model.evaluate(X_train, y_train, verbose = 0)
results_test = model.evaluate(X_test, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the test set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the test set is 0.64...
# ...whereas the accuracy on the training set is 0.87!

# %% [markdown]
# ☝️ In our *over-parametrized network*, ***some neurons became too specific to the given training data***, preventing the network from generalizing to new data.
#
# 😕 This led to some overfitting...!

# %% [markdown]
# ❓ **Question: studying the impact of regularization on the Neural Net**❓
#
# * Change the previous code to integrate a L2 or L1 regularizer to your Dense Layers.

# %%
# YOUR CODE HERE
from tensorflow.keras import regularizers

reg_l1 = regularizers.L1(0.01)
reg_l2 = regularizers.L2(0.01)
reg_l1_l2 = regularizers.l1_l2(l1=0.005, l2=0.0005)

# RUN THIS CELL

# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dense(10, activation='relu', kernel_regularizer=reg_l1))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model compilation
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 3. Training 
history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
                    batch_size = 16, 
                    verbose=0)

# 4. Evaluation
results_train = model.evaluate(X_train, y_train, verbose = 0)
results_test = model.evaluate(X_test, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the test set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the test set is 0.67...
# ...whereas the accuracy on the training set is 0.85!

# %%
# YOUR CODE HERE
from tensorflow.keras import regularizers

reg_l1 = regularizers.L1(0.01)
reg_l2 = regularizers.L2(0.01)
reg_l1_l2 = regularizers.l1_l2(l1=0.005, l2=0.0005)

# RUN THIS CELL

# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dense(10, activation='relu', kernel_regularizer=reg_l2))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model compilation
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 3. Training 
history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
                    batch_size = 16, 
                    verbose=0)

# 4. Evaluation
results_train = model.evaluate(X_train, y_train, verbose = 0)
results_test = model.evaluate(X_test, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the test set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the test set is 0.67...
# ...whereas the accuracy on the training set is 0.86!

# %%
# YOUR CODE HERE
from tensorflow.keras import regularizers

reg_l1 = regularizers.L1(0.01)
reg_l2 = regularizers.L2(0.01)
reg_l1_l2 = regularizers.l1_l2(l1=0.005, l2=0.0005)

# RUN THIS CELL

# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dense(10, activation='relu', kernel_regularizer=reg_l1_l2))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model compilation
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 3. Training 
history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
                    batch_size = 16, 
                    verbose=0)

# 4. Evaluation
results_train = model.evaluate(X_train, y_train, verbose = 0)
results_test = model.evaluate(X_test, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the test set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the test set is 0.68...
# ...whereas the accuracy on the training set is 0.85!

# %% [markdown]
# ### (2.4) Dropout layers

# %% [markdown]
# ✂️ **`Dropout Layers`** ✂️
#
# - ✅ They are super straightforward to code
# - 👩🏻‍🏫 But what is going on _"under the hood"_ ? (You love this expression right? 😏)
#
# <u><i>Introduction to Dropout Layers</i><u>
#
# * Their role is to randomly cancel the output of some neurons during the training phase
# * It prevents the network from getting too specific to the input data. With Dropout layers,
#     - No neuron can overspecialize in learning a pattern of the dataset because its output is sometimes canceled by the Dropout Layer
#     - Overall, a Dropout Layer forces the information of an input to be spread across multiple neurons instead of only one specific neuron
#
# <details>
#     <summary><i>[optional] Click this for further explanations about Dropout Layers</i></summary>
#
# 🤔 Remember what we said about ***neurons becoming too specific***?
#
# ---
#
# ⚽️ *An analogy with football:*
#
# Think about a football team. There are 11 players on the pitch, but there are also players on the bench, what for ?
# * The coach may want to substitute injured or tired players during the game
# * The team may be:
#     - losing the game and willing to replace a midfielder with a more ***versatile player*** who can be more offensive (= ***mix of*** midfielder/attacker role)
#     - winning the game and would like to secure the result by replacing a midfielder with a more ***versatile player*** who can be more defense ( = ***mix of*** midfielder/defense role)
#
# 💡 Well, in a Neural Net, there is also a risk that a neuron over-specializes in detecting one pattern, whereas it would be more advisable to keep it more versatile.
#
# ---
#
# 📚 **The goal of [Dropout layers](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout) is to prevent neurons from over-specializing**.
#
# 🧑🏻‍🏫 How do Dropout layers work?
#
# * 👉 When we apply a **Dropout rate** of 20% to a layer $k$, 20% of the ***selected neurons*** will have their ***weights temporarily set to 0*** , which has the following consequences:
#     1. A neuron computed at layer $k+1$ considers all the weights as usual, but since some of them were temporarily set to 0, they were “ignored” while creating the neurons of this layer $k+1$
#     2. Once a batch of data points have been seen by the Neural Network (**forward propagation**) and 80% of the weights in a layer optimized/updated (**backward propagation** with the **adam** optimizer), the Neural Network moves on to the forward propagation of the next batch, where it will use:
#         * 80% of the weights, those which were updated
#         * 20% of weights, those which were previously ignored (which kept their original values and were actually not set in stone to 0 but just temporarily)
#         * Based on these weights, we will again go through this Dropout Layer which again is going to ignore 20% of the weights of a given layer temporarily. Be careful, the selection of these 20% being random, the weights which will be ignored this time won't necessarily be the same weights as before!
#
# * 👉 Think about the ***Dropout Rate*** as a ***sampling with replacement***
#
# * 👉 By ***randomly shutting down*** different neurons at different epochs, we ***force the datapoints*** to be analyzed by different neurons. At the end of the day, these neurons will become ***more versatile*** instead of overspecializing!
#
# </details>
#
# ---

# %% [markdown]
# ❓ **Question: studying the impact of Dropout layers on the Neural Net**❓
#
# * Include some Dropout layers in the architecture of your original model.
# _(Don't add regularizers here)_
#
# * What can you observe about the convergence of your model? What about its ability to generalize?

# %%
# YOUR CODE HERE
# 1. Model Architecture
model = models.Sequential()
model.add(layers.Dense(25, activation='relu', input_dim=10))
model.add(layers.Dropout(rate=0.2))
model.add(layers.Dense(10, activation='relu', kernel_regularizer=reg_l1_l2))
model.add(layers.Dropout(rate=0.2))
model.add(layers.Dense(8, activation='softmax'))

# 2. Model compilation
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 3. Training 
history = model.fit(X_train, y_train,
                    validation_split = 0.3,
                    epochs = 300,           # Notice that we are not using any Early Stopping Criterion
                    batch_size = 16, 
                    verbose=0)

# 4. Evaluation
results_train = model.evaluate(X_train, y_train, verbose = 0)
results_test = model.evaluate(X_test, y_test, verbose = 0)


# 5. Looking back at what happened during the training phase
print(f'The accuracy on the test set is {results_test[1]:.2f}...')
print(f'...whereas the accuracy on the training set is {results_train[1]:.2f}!')
plot_loss_accuracy(history)
# Out:
# The accuracy on the test set is 0.74...
# ...whereas the accuracy on the training set is 0.79!

# %% [markdown]
# <u><b>Conclusions:</b></u>
#
# * ❗️ If you train a Neural Network too much (too many layers, too many neurons and/or too many epochs), it will overfit very quickly
#
# * 🥊 To prevent overfitting in Deep Learning, you can use Early Stopping, Regularization and Dropout Layers.
#
# * ❗️ Be careful, if you use these techniques, you might end up on the other spectrum of the performance where you model would underfit the dataset!
#
# * 🆗 You could potentially look at the batch size but we usually use 16 or 32. And as the French Computer Scientist [**Yann Lecun**](https://en.wikipedia.org/wiki/Yann_LeCun) said (Facebook x NYU):
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/deep_learning_yann_lecun_batch_size.png" alt="batch_size_yann_lecun" width="400" height="250">

# %% [markdown]
# 🏁 Congratulations!
#
# 💾 Do not forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move to the next challenge!
